# %%
from DataManagement import ImageSequencer
import numpy as np
import torch
import matplotlib.pyplot as plt

# %%
root_path = "C:\\Users\\mgussert\\Downloads\\random_walk_data_2"
sequencer = ImageSequencer([root_path], image_rows=64, image_cols=64)
# Out:
# sequencing file 0 of length 25
# sequencing file 1 of length 25
# sequencing file 2 of length 25
# sequencing file 3 of length 25
# sequencing file 4 of length 25
# sequencing file 5 of length 25
# sequencing file 6 of length 25
# sequencing file 7 of length 25
# sequencing file 8 of length 25
# sequencing file 9 of length 25
# sequencing file 10 of length 25
# sequencing file 11 of length 25
# sequencing file 12 of length 25
# sequencing file 13 of length 25
# sequencing file 14 of length 25
# sequencing file 15 of length 25
# sequencing file 16 of length 25
# sequencing file 17 of length 25
# sequencing file 18 of length 25
# sequencing file 19 of length 25
# sequencing file 20 of length 25
# sequencing file 21 of length 25
# sequencing file 22 of length 25
# sequencing file 23 of length 25
# sequencing file 24 of length 25
# sequencing file 25 of length 25
# sequencing file 26 of length 25
# sequencing file 27 of length 25
# sequencing file 28 of length 25
# ...

# %%
X, A, T = sequencer.get_run(40)

# %%
print(X.shape)
# Out:
# torch.Size([25, 2, 64, 64, 3])

# %%
plt.imshow(X[5,1])
